# %% [markdown]
# ## Internações dos pacientes Residentes de Fortaleza
# - Todos os pacientes residem em Fortaleza
# - 53 Colunas
# - 867.020 Linhas
#
# ### Sobre o Paciente
# | Nome Coluna | Obs | Descrição |
# | --- | --- | --- |
# | MUNIC_RES | Constant "Fortaleza" | Município de Residência do Paciente
# | CIDADE | Constant "Fortaleza" (9.8%) missing values | Cidade de Residência do Paciente
# | BAIRRO | (9.8%) missing values | Bairro de Residência do Paciente
# | LOGRADOURO | (9.8%) missing values | Rua de Residência do Paciente
# | UF | Constant "CE" (9.8%) missing values | UF de Residência do Paciente
# | CEP | | CEP do paciente.
# | NASC | High cardinality | Data de nascimento do paciente (aaaammdd).
# | SEXO | Feminino 58,4% & 41,6% Masculino | Sexo do paciente.
# | RACA_COR | (33.3%) missing values { top1 - Parda } | Raça/Cor do paciente.
# | INSTRU | (99.5%) missing values | Grau de instrução do paciente.
# | NACIONAL | High cardinality (99,3%) Brasil | Código da nacionalidade do paciente.
# | COD_IDADE | [ Dias, Meses, Anos ] | Unidade de medida da idade.
# | IDADE | (3.8%) zeros |
# | IDADE_REAL |  (8.4%) zeros | Dias e Meses convertidos em 0 Anos
# | GESTRISCO | Não > 99,9% & < 0,1% Sim | Indicador se é gestante de risco.
# | MORTE | Não 96,3% & 3,7% Sim | Indica Óbito
# | CID_MORTE | High cardinality (99.4%) missing values { top1 - Parada Cardiaca }| CID da morte.
#
# ### Sobre a Unidade Hospitalar
# | Nome Coluna | Obs | Descrição |
# | --- | --- | --- |
# | UF_ZI | High cardinality 109 values (5.7%) missing values | Município Gestor.
# | MUNIC_MOV | High cardinality 109 values | Município do Estabelecimento.
# | CGC_HOSP | (6.5%) missing values | CNPJ do Estabelecimento.
# | CNES | | Código CNES do hospital.
# | CNPJ_MANT | (31.2%) missing values | CNPJ da mantenedora.
# | GESTAO | Municipal 94,3% & 5,7% Estadual | Indica o tipo de gestão do hospital.
# | NAT_JUR | (1.1%) missing values | Natureza jurídica do Estabelecimento, conforme a Comissão Nacional de Classificação - CONCLA
# | NATUREZA | (68.9%) zeros | Natureza jurídica do hospital (com conteúdo até maio/12). Era utilizada a classificação de Regime e Natureza.
#
# ### Sobre a Internação
# | Nome Coluna | Obs | Descrição |
# | --- | --- | --- |
# | N_AIH | | Número da AIH.
# | IDENT | Principal 97,7% & 2,3% Longa Permanência | Identificação do tipo da AIH.
# | HOMONIMO | Não 95,7% & 4,3% Sim | Indicador se o paciente da AIH é homônimo do paciente de outra AIH.
# | ANO_CMPT | [ 2014 - 2019 ] | Ano de processamento da AIH, no formato aaaa.
# | MES_CMPT | [ 1 - 12 ] | Mês de processamento da AIH, no formato mm.
# | DIAG_PRINC | High cardinality { top1 - Parto & top2 - Pneumonia resp. } | Código do diagnóstico principal (CID10).
# | CID_ASSO | High cardinality (> 99.9%) missing values { top1 - Ictericia Neonatal } | CID causa.
# | COMPLEX | Média 91,3% & 8,7% Alta | Complexidade
# | ESPEC | { top1 - Cirurgia } | Especialidade do Leito
# | DT_INTER | High cardinality | Data de internação no formato aaammdd.
# | DT_SAIDA | High cardinality | Data de saída, no formato aaaammdd.
# | COBRANCA | (60.8%) Alta melhorado	| Motivo de Saída/Permanência
# | CAR_INT | (78,5%) Urgência | Caráter da internação.
# | MARCA_UTI | (94,9%) Não utilizou UTI | Indica qual o tipo de UTI utilizada pelo paciente.
# | UTI_MES_TO | (94.9%) zeros | Quantidade de dias de UTI no mês.
# | UTI_INT_TO | (98.0%) zeros | Quantidade de diárias em unidade intermediaria.
# | QT_DIARIAS | (5.0%) zeros | Quantidade de diárias.
# | DIAR_ACOM | (42.0%) zeros | Quantidade de diárias de acompanhante.
# | DIAS_PERM | (6.3%) zeros | Dias de Permanência.
# | IND_VDRL | Não 85,4% & 14,6% Sim | Indica exame VDRL.
# | FINANC | | Tipo de financiamento.
# | REGCT | (89,8%) Sem Regra Contratual | Regra contratual.
# | PROC_SOLIC | | Procedimento solicitado.
# | PROC_REA | | Procedimento realizado.
#
# ### Sobre a Valores
# | Nome Coluna | Obs | Descrição |
# | --- | --- | --- |
# | VAL_SH | | Valor de serviços hospitalares.
# | VAL_SP | | Valor de serviços profissionais.
# | VAL_TOT | | Valor total da AIH.
# | VAL_UTI | (94.9%) zeros | Valor de UTI.

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip -qqq

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# coding: utf-8

import pandas as pd

INTERNACOES = "/content/drive/MyDrive/Colab Notebooks/internacoes_fortaleza.csv"
PROFILE_REPORT = "/content/drive/MyDrive/Colab Notebooks/explorative_profileReport_fortaleza.html"

# %%
df = pd.read_csv(INTERNACOES)
df.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    ANO_CMPT  MES_CMPT      CGC_HOSP          N_AIH       CEP        NASC  \
# 0      2014         1  5.268526e+12  2314100004865  60870576  2013-05-19
# 1      2014         1  5.268526e+12  2314100004876  60851290  2013-05-30
#
#    UTI_MES_TO  UTI_INT_TO  DIAR_ACOM  QT_DIARIAS  ...           GESTAO  \
# 0           0           0          0          10  ...   Estadual plena
# 1           0           0          0           5  ...   Estadual plena
#
#         IDENT  INSTRU          MARCA_UTI  NACIONAL              NAT_JUR  \
# 0   Principal     NaN   Não utilizou UTI    Brasil   Associação Privada
# 1   Principal     NaN   Não utilizou UTI    Brasil   Associação Privada
#
#   RACA_COR                  REGCT        SEXO  IDADE_REAL
# ...

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title= "internacoes_fortaleza_ce", explorative=True, correlations=None)

# %%
profile.to_file(PROFILE_REPORT)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
